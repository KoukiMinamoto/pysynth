# %%
from synth import *
from interface import *
from sampler import Sampler
from oscillator import SineWave, TriangleWave, ToufuWave
from amplifier import SimpleAmp, WavWriter
from controller import Envelope, ArduinoController
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
synth = Series(pitch=440, rate=44100, bufsize=512)

# %%
synth.stack(MIDIkeyboard())
#synth.stack(MonoMeledy(72, 3.0))

# %%
#sam = synth.stack(Sampler(wavefile="wizavo_outfile/men/wa-_edited.wav"))
osc = synth.stack(ToufuWave(interval=12))
#sam.loopON(pos=0.5, length=0.1, fade=0.9)
#amp = synth.stack(WavWriter(volume=0.1, file_name="result/melo_ha-.wav"))
amp = synth.stack(SimpleAmp(volume=0.5))

# %%
env = Envelope(A=0.01, D=0.03, S=0.5, R=0.2)
#env3 = Envelope(A=0.05, D=0.3, S=0.0, R=0.2)
#env3.assign(osc.fine, scale=100.)
#env2 = ArduinoController(com='/dev/cu.usbmodem14301', baudrate=9600)
#env2.assign(osc.fine, scale=100.)
env.assign(amp.amp)
synth.implement(env)
#synth.implement(env2)
#synth.implement(env3)

# %%
synth.completed()
synth.play()
# Out:
# input_id:  0
# Your Synth is completed!!
# Structure:  [<interface.MIDIkeyboard object at 0x126bc5dd8>, <oscillator.ToufuWave object at 0x126bdbe48>, <amplifier.SimpleAmp object at 0x126bdbfd0>]
# [[149, 36, 127, 0], 1026]
# [[149, 36, 0, 0], 1201]
# [[149, 36, 127, 0], 1272]
# [[149, 36, 0, 0], 1403]
# [[149, 36, 127, 0], 1451]
# [[149, 36, 0, 0], 1590]
# [[149, 36, 127, 0], 2629]
# [[149, 36, 0, 0], 2776]
# [[149, 36, 127, 0], 2859]
# [[149, 36, 0, 0], 2986]
# [[149, 36, 127, 0], 3042]
# [[149, 36, 0, 0], 3181]
# [[149, 36, 127, 0], 3228]
# [[149, 36, 0, 0], 3389]
# [[149, 36, 127, 0], 3762]
# [[149, 36, 0, 0], 3933]
# [[149, 36, 127, 0], 4003]
# [[149, 36, 0, 0], 4123]
# [[149, 36, 127, 0], 4201]
# [[149, 36, 0, 0], 4337]
# [[149, 36, 127, 0], 4385]
# [[149, 36, 0, 0], 4564]
# [[149, 36, 127, 0], 4983]
# [[149, 36, 0, 0], 5132]
# [[149, 36, 127, 0], 5166]
# [[149, 36, 0, 0], 5327]
# [[149, 36, 127, 0], 7215]
# [[149, 36, 0, 0], 7376]
# [[149, 36, 127, 0], 7464]
# [[149, 36, 0, 0], 7649]
# [[149, 36, 127, 0], 7682]
# [[149, 36, 0, 0], 7842]
# [[149, 36, 127, 0], 7856]
# [[149, 36, 0, 0], 8003]
# [[149, 40, 127, 0], 8113]
# [[149, 40, 0, 0], 8290]
# [[149, 49, 127, 0], 8495]
# [[149, 54, 127, 0], 8534]
# [[149, 49, 0, 0], 8541]
# [[149, 80, 127, 0], 8643]
# [[149, 54, 0, 0], 8743]
# [[149, 72, 127, 0], 8780]
# [[149, 58, 127, 0], 8840]
# [[149, 80, 0, 0], 8858]
# [[149, 72, 0, 0], 8933]
# [[149, 85, 127, 0], 9002]
# [[149, 58, 0, 0], 9011]
# [[149, 92, 127, 0], 9070]
# [[149, 92, 0, 0], 9111]
# [[149, 85, 0, 0], 9214]
# [[149, 66, 127, 0], 9280]
# [[149, 97, 127, 0], 9365]
# [[149, 66, 0, 0], 9410]
# [[149, 97, 0, 0], 9601]
# [[149, 96, 127, 0], 9702]
# [[149, 97, 127, 0], 9769]
# [[149, 96, 0, 0], 9945]
# [[149, 97, 0, 0], 10032]
# [[149, 36, 127, 0], 10634]
# [[149, 36, 0, 0], 10695]
# [[149, 37, 127, 0], 10749]
# [[149, 37, 0, 0], 10830]
# [[149, 44, 127, 0], 10841]
# [[149, 41, 127, 0], 10887]
# [[149, 44, 0, 0], 10893]
# [[149, 42, 127, 0], 10978]
# [[149, 41, 0, 0], 11061]
# [[149, 42, 0, 0], 11167]
# [[149, 46, 127, 0], 11191]
# [[149, 76, 127, 0], 11336]
# [[149, 46, 0, 0], 11349]
# [[149, 39, 127, 0], 11447]
# [[149, 55, 127, 0], 11514]
# [[149, 39, 0, 0], 11566]
# [[149, 84, 127, 0], 11567]
# [[149, 76, 0, 0], 11582]
# [[149, 55, 0, 0], 11708]
# [[149, 81, 127, 0], 11814]
# [[149, 84, 0, 0], 11818]
# [[149, 58, 127, 0], 11916]
# [[149, 92, 127, 0], 11985]
# [[149, 81, 0, 0], 12007]
# [[149, 58, 0, 0], 12014]
# [[149, 58, 127, 0], 12024]
# [[149, 93, 127, 0], 12089]
# [[149, 58, 0, 0], 12131]
# [[149, 90, 127, 0], 12185]
# [[149, 92, 0, 0], 12231]
# [[149, 93, 0, 0], 12308]
# [[149, 96, 127, 0], 12432]
# [[149, 90, 0, 0], 12442]
# [[149, 98, 127, 0], 12554]
# [[149, 96, 0, 0], 12589]
# [[149, 91, 127, 0], 12650]
# [[149, 98, 0, 0], 12773]
# [[149, 91, 0, 0], 12781]
# [[149, 36, 127, 0], 24764]
# [[149, 36, 0, 0], 24974]
# [[149, 36, 127, 0], 25115]
# [[149, 36, 0, 0], 25289]
# [[149, 36, 127, 0], 25435]
# [[149, 36, 0, 0], 25557]
# [[149, 36, 127, 0], 25616]
# [[149, 36, 0, 0], 25795]
# [[149, 36, 127, 0], 25973]
# [[149, 36, 0, 0], 26121]
# [[149, 36, 127, 0], 26333]
# [[149, 36, 0, 0], 26659]
# [[149, 36, 127, 0], 26733]
# [[149, 36, 0, 0], 26909]
# [[149, 36, 127, 0], 26931]
# [[149, 36, 0, 0], 27123]
# [[149, 36, 127, 0], 27297]
# [[149, 36, 0, 0], 27474]
# [[149, 36, 127, 0], 27648]
# [[149, 36, 0, 0], 27821]
# [[149, 36, 127, 0], 27932]
# [[149, 36, 0, 0], 28124]
# [[149, 36, 127, 0], 28305]
# [[149, 36, 0, 0], 28449]
# [[149, 36, 127, 0], 28515]
# [[149, 36, 0, 0], 28859]
# [[149, 40, 127, 0], 29132]
# [[149, 40, 0, 0], 29271]
# [[149, 40, 127, 0], 29331]
# [[149, 40, 0, 0], 29467]
# [[149, 40, 127, 0], 29511]
# [[149, 40, 0, 0], 29639]
# [[149, 40, 127, 0], 29706]
# [[149, 40, 0, 0], 29779]
# [[149, 40, 127, 0], 29874]
# [[149, 40, 0, 0], 29977]
# [[149, 40, 127, 0], 30038]
# [[149, 40, 0, 0], 30138]
# [[149, 40, 127, 0], 30201]
# [[149, 40, 0, 0], 30313]
# [[149, 40, 127, 0], 30369]
# [[149, 40, 0, 0], 30478]
# [[149, 40, 127, 0], 30530]
# [[149, 40, 0, 0], 30646]
# [[149, 40, 127, 0], 30689]
# [[149, 40, 0, 0], 30853]
# [[149, 40, 127, 0], 30867]
# [[149, 40, 0, 0], 31024]
# [[149, 40, 127, 0], 31040]
# [[149, 40, 0, 0], 31225]
# [[149, 36, 127, 0], 31759]
# [[149, 36, 0, 0], 31901]
# [[149, 38, 127, 0], 31942]
# [[149, 38, 0, 0], 32259]
# [[149, 40, 127, 0], 32262]
# [[149, 40, 0, 0], 32389]
# [[149, 36, 127, 0], 32624]
# [[149, 38, 127, 0], 32995]
# [[149, 36, 0, 0], 33003]
# [[149, 38, 0, 0], 33394]
# [[149, 40, 127, 0], 33583]
# [[149, 40, 0, 0], 33955]
# [[149, 36, 127, 0], 34105]
# [[149, 38, 127, 0], 34463]
# [[149, 36, 0, 0], 34481]
# [[149, 40, 127, 0], 34841]
# [[149, 38, 0, 0], 34915]
# [[149, 40, 0, 0], 35457]
# [[149, 41, 127, 0], 35469]
# [[149, 41, 0, 0], 35851]
# [[149, 38, 127, 0], 35864]
# [[149, 38, 0, 0], 36061]
# [[149, 36, 127, 0], 36102]
# [[149, 36, 0, 0], 36259]
# [[149, 36, 127, 0], 36428]
# [[149, 36, 0, 0], 36583]
# [[149, 38, 127, 0], 36665]
# [[149, 40, 127, 0], 36891]
# [[149, 38, 0, 0], 36945]
# [[149, 40, 0, 0], 37125]
# [[149, 36, 127, 0], 37188]
# [[149, 38, 127, 0], 37409]
# [[149, 36, 0, 0], 37652]
# [[149, 40, 127, 0], 37661]
# [[149, 38, 0, 0], 37803]
# [[149, 41, 127, 0], 38207]
# [[149, 40, 0, 0], 38223]
# [[149, 43, 127, 0], 38352]
# [[149, 44, 127, 0], 38478]
# [[149, 41, 0, 0], 38479]
# [[149, 43, 0, 0], 38541]
# [[149, 47, 127, 0], 38716]
# [[149, 45, 127, 0], 38821]
# [[149, 47, 0, 0], 38834]
# [[149, 44, 0, 0], 38843]
# [[149, 46, 127, 0], 39008]
# [[149, 48, 127, 0], 39047]
# [[149, 45, 0, 0], 39158]
# [[149, 46, 0, 0], 39175]
# [[149, 51, 127, 0], 39203]
# [[149, 50, 127, 0], 39298]
# [[149, 51, 0, 0], 39343]
# [[149, 49, 127, 0], 39380]
# [[149, 48, 0, 0], 39453]
# [[149, 52, 127, 0], 39623]
# [[149, 55, 127, 0], 39658]
# [[149, 50, 0, 0], 39665]
# [[149, 49, 0, 0], 39717]
# [[149, 54, 127, 0], 39852]
# [[149, 55, 0, 0], 39910]
# [[149, 53, 127, 0], 39954]
# [[149, 52, 0, 0], 40048]
# [[149, 54, 0, 0], 40212]
# [[149, 53, 0, 0], 40251]
# [[149, 99, 127, 0], 41150]
# [[149, 96, 127, 0], 41199]
# [[149, 99, 0, 0], 41240]
# [[149, 96, 0, 0], 41321]
# [[149, 98, 127, 0], 41341]
# [[149, 97, 127, 0], 41407]
# [[149, 98, 0, 0], 41436]
# [[149, 97, 0, 0], 41491]
# [[149, 95, 127, 0], 41533]
# [[149, 92, 127, 0], 41590]
# [[149, 95, 0, 0], 41629]
# [[149, 92, 0, 0], 41703]
# [[149, 94, 127, 0], 41720]
# [[149, 93, 127, 0], 41789]
# [[149, 94, 0, 0], 41804]
# [[149, 93, 0, 0], 41882]
# [[149, 91, 127, 0], 41912]
# [[149, 88, 127, 0], 42017]
# [[149, 91, 0, 0], 42021]
# [[149, 88, 0, 0], 42121]
# [[149, 90, 127, 0], 42127]
# [[149, 90, 0, 0], 42220]
# [[149, 89, 127, 0], 42232]
# [[149, 87, 127, 0], 42325]
# [[149, 89, 0, 0], 42327]
# [[149, 84, 127, 0], 42425]
# [[149, 87, 0, 0], 42442]
# [[149, 86, 127, 0], 42529]
# [[149, 84, 0, 0], 42545]
# [[149, 85, 127, 0], 42629]
# [[149, 86, 0, 0], 42629]
# [[149, 85, 0, 0], 42729]
# [[149, 83, 127, 0], 42738]
# [[149, 80, 127, 0], 42843]
# [[149, 83, 0, 0], 42849]
# [[149, 82, 127, 0], 42953]
# [[149, 80, 0, 0], 42960]
# [[149, 82, 0, 0], 43036]
# [[149, 81, 127, 0], 43061]
# [[149, 81, 0, 0], 43130]
# [[149, 79, 127, 0], 43145]
# [[149, 79, 0, 0], 43265]
# [[149, 76, 127, 0], 43278]
# [[149, 78, 127, 0], 43367]
# [[149, 76, 0, 0], 43384]
# [[149, 78, 0, 0], 43468]
# [[149, 77, 127, 0], 43469]
# [[149, 77, 0, 0], 43569]
# [[149, 75, 127, 0], 43569]
# [[149, 72, 127, 0], 43675]
# [[149, 75, 0, 0], 43689]
# [[149, 74, 127, 0], 43777]
# [[149, 72, 0, 0], 43791]
# [[149, 74, 0, 0], 43868]
# [[149, 73, 127, 0], 43868]
# [[149, 73, 0, 0], 43969]
# [[149, 71, 127, 0], 43969]
# [[149, 68, 127, 0], 44053]
# [[149, 71, 0, 0], 44081]
# [[149, 70, 127, 0], 44171]
# [[149, 68, 0, 0], 44190]
# [[149, 69, 127, 0], 44257]
# [[149, 70, 0, 0], 44272]
# [[149, 69, 0, 0], 44360]
# [[149, 36, 127, 0], 48433]
# [[149, 36, 0, 0], 48634]
# [[149, 38, 127, 0], 48899]
# [[149, 38, 0, 0], 49111]
# [[149, 40, 127, 0], 49449]
# [[149, 40, 0, 0], 50271]
# [[149, 42, 127, 0], 50386]
# [[149, 42, 0, 0], 50657]
# [[149, 43, 127, 0], 50837]
# [[149, 43, 0, 0], 51038]
# [[149, 43, 127, 0], 51604]
# [[149, 43, 0, 0], 51842]
# [[149, 41, 127, 0], 52047]
# [[149, 41, 0, 0], 52350]
# [[149, 43, 127, 0], 52585]
# [[149, 43, 0, 0], 52789]
# [[149, 40, 127, 0], 52836]
# [[149, 40, 0, 0], 53045]
# [[149, 38, 127, 0], 53115]
# [[149, 38, 0, 0], 53533]
# [[149, 43, 127, 0], 53726]
# [[149, 40, 127, 0], 54020]
# [[149, 43, 0, 0], 54061]
# [[149, 40, 0, 0], 54209]
# [[149, 44, 127, 0], 54554]
# [[149, 44, 0, 0], 54829]
# [[149, 43, 127, 0], 54978]
# [[149, 43, 0, 0], 55068]
# [[149, 40, 127, 0], 55141]
# [[149, 40, 0, 0], 55363]
# [[149, 43, 127, 0], 55462]
# [[149, 43, 0, 0], 55700]
# [[149, 40, 127, 0], 55726]
# [[149, 40, 0, 0], 55934]
# [[149, 36, 127, 0], 56770]
# [[149, 36, 0, 0], 56972]
# [[149, 38, 127, 0], 57416]
# [[149, 38, 0, 0], 58381]
# [[149, 36, 127, 0], 58541]
# [[149, 36, 0, 0], 59142]
# [[149, 38, 127, 0], 59144]
# [[149, 40, 127, 0], 59395]
# [[149, 38, 0, 0], 59440]
# [[149, 40, 0, 0], 59741]
# [[149, 38, 127, 0], 59742]
# [[149, 38, 0, 0], 59993]
# [[149, 36, 127, 0], 60071]
# [[149, 36, 0, 0], 60448]
# [[149, 38, 127, 0], 60590]
# [[149, 40, 127, 0], 61102]
# [[149, 38, 0, 0], 61185]
# [[149, 43, 127, 0], 61910]
# [[149, 40, 0, 0], 61957]
# [[149, 40, 127, 0], 62189]
# [[149, 43, 0, 0], 62266]
# [[149, 36, 127, 0], 62463]
# [[149, 40, 0, 0], 62511]
# [[149, 36, 0, 0], 62859]
# [[149, 38, 127, 0], 63139]
# [[149, 36, 127, 0], 64127]
# [[149, 38, 0, 0], 64183]
# [[149, 38, 127, 0], 64711]
# [[149, 36, 0, 0], 64743]
# [[149, 38, 0, 0], 64992]
# [[149, 40, 127, 0], 64994]
# [[149, 43, 127, 0], 65272]
# [[149, 40, 0, 0], 65299]
# [[149, 43, 0, 0], 65557]
# [[149, 43, 127, 0], 65622]
# [[149, 43, 0, 0], 65902]
# [[149, 40, 127, 0], 65937]
# [[149, 40, 0, 0], 66177]
# [[149, 40, 127, 0], 66238]
# [[149, 40, 0, 0], 66505]
# [[149, 38, 127, 0], 66824]
# [[149, 38, 0, 0], 67194]
# [[149, 43, 127, 0], 67371]
# [[149, 43, 0, 0], 67701]
# [[149, 40, 127, 0], 67763]
# [[149, 40, 0, 0], 68043]
# [[149, 38, 127, 0], 68176]
# [[149, 38, 0, 0], 68316]
# [[149, 43, 127, 0], 68622]
# [[149, 40, 127, 0], 68901]
# [[149, 43, 0, 0], 68904]
# [[149, 40, 0, 0], 69079]
# [[149, 36, 127, 0], 69177]
# [[149, 36, 0, 0], 69487]
# [[149, 38, 127, 0], 69520]
# [[149, 38, 0, 0], 69840]
# [[149, 36, 127, 0], 69851]
# [[149, 36, 0, 0], 70130]
# [[149, 38, 127, 0], 70179]
# [[149, 38, 0, 0], 70311]
# [[149, 36, 127, 0], 70565]
# [[149, 36, 0, 0], 70884]
# [[149, 38, 127, 0], 70893]
# [[149, 40, 127, 0], 71145]
# [[149, 38, 0, 0], 71157]
# [[149, 40, 0, 0], 71963]
# [[149, 36, 127, 0], 72663]
# [[149, 36, 0, 0], 73038]
# [[149, 38, 127, 0], 73277]
# [[149, 38, 0, 0], 73581]
# [[149, 40, 127, 0], 73740]
# [[149, 43, 127, 0], 74469]
# [[149, 40, 0, 0], 74475]
# [[149, 40, 127, 0], 74750]
# [[149, 43, 0, 0], 74788]
# [[149, 40, 0, 0], 75070]
# [[149, 36, 127, 0], 75135]
# [[149, 36, 0, 0], 75439]
# [[149, 38, 127, 0], 75707]
# [[149, 38, 0, 0], 76523]
# [[149, 36, 127, 0], 76707]
# [[149, 36, 0, 0], 77382]
# [[149, 38, 127, 0], 77426]
# [[149, 38, 0, 0], 77626]
# [[149, 40, 127, 0], 77662]
# [[149, 43, 127, 0], 77967]
# [[149, 40, 0, 0], 77995]
# [[149, 43, 0, 0], 78236]
# [[149, 43, 127, 0], 78318]
# [[149, 43, 0, 0], 78575]
# [[149, 40, 127, 0], 78643]
# [[149, 40, 0, 0], 78850]
# [[149, 40, 127, 0], 78929]
# [[149, 40, 0, 0], 79129]
# [[149, 38, 127, 0], 79310]
# [[149, 38, 0, 0], 79572]
# [[149, 36, 127, 0], 79585]
# [[149, 36, 0, 0], 79771]
# [[149, 43, 127, 0], 79948]
# [[149, 43, 0, 0], 80208]
# [[149, 40, 127, 0], 80455]
# [[149, 40, 0, 0], 80660]
# [[149, 36, 127, 0], 81252]
# [[149, 36, 0, 0], 81526]
# [[149, 38, 127, 0], 81638]
# [[149, 38, 0, 0], 81913]
# [[149, 36, 127, 0], 82012]
# [[149, 36, 0, 0], 82266]
# [[149, 36, 127, 0], 82431]
# [[149, 36, 0, 0], 82644]
# [[149, 38, 127, 0], 82798]
# [[149, 38, 0, 0], 83023]
# [[149, 40, 127, 0], 83050]
# [[149, 36, 127, 0], 84099]
# [[149, 40, 0, 0], 84124]
# [[149, 36, 0, 0], 84493]
# [[149, 38, 127, 0], 84690]
# [[149, 38, 0, 0], 85097]
# [[149, 43, 127, 0], 85601]
# [[149, 43, 0, 0], 86074]
# [[149, 36, 127, 0], 86286]
# [[149, 36, 0, 0], 86577]
# [[149, 38, 127, 0], 86850]
# [[149, 38, 0, 0], 87108]
# [[149, 38, 127, 0], 87487]
# [[149, 38, 0, 0], 87795]
# [[149, 36, 127, 0], 87846]
# [[149, 36, 0, 0], 88070]
# [[149, 38, 127, 0], 88461]
# [[149, 38, 0, 0], 88683]
# [[149, 40, 127, 0], 88930]
# [[149, 43, 127, 0], 89670]
# [[149, 40, 0, 0], 89690]
# [[149, 40, 127, 0], 89955]
# [[149, 43, 0, 0], 89961]
# [[149, 36, 127, 0], 90223]
# [[149, 40, 0, 0], 90282]
# [[149, 36, 0, 0], 90605]
# [[149, 38, 127, 0], 90872]
# [[149, 38, 0, 0], 91843]
# [[149, 36, 127, 0], 91848]
# [[149, 36, 0, 0], 92483]
# [[149, 38, 127, 0], 92490]
# [[149, 38, 0, 0], 92766]
# [[149, 43, 127, 0], 92944]
# [[149, 43, 0, 0], 93303]
# [[149, 36, 127, 0], 93444]
# [[149, 36, 0, 0], 94002]
# [[149, 38, 127, 0], 94024]
# [[149, 38, 0, 0], 94284]
# [[149, 36, 127, 0], 94382]
# [[149, 36, 0, 0], 94548]
# [[149, 38, 127, 0], 94798]
# [[149, 38, 0, 0], 95238]
# [[149, 36, 127, 0], 126153]
# [[149, 36, 0, 0], 126382]
# [[149, 36, 127, 0], 126531]
# [[149, 36, 0, 0], 126684]
# [[149, 36, 127, 0], 126764]
# [[149, 36, 0, 0], 126899]
# [[149, 36, 127, 0], 127197]
# [[149, 36, 0, 0], 127319]
# [[149, 36, 127, 0], 127390]
# [[149, 36, 0, 0], 127551]
# [[149, 97, 127, 0], 130666]
# [[149, 97, 0, 0], 131058]
# [[149, 77, 127, 0], 360806]
# [[149, 77, 0, 0], 361011]
